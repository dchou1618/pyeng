# %%
import pandas as pd

from sqlite3 import connect

from datetime import datetime

# %%
conn = connect(':memory:')

# %% [markdown]
# ### Grouped Static Data

# %%
# Objective: Predicting Attrition
df_hr = pd.read_csv("./sample-data/hr_data.csv")
df_hr = df_hr.loc[:,(~df_hr.columns.isin({"Employee_Name"})) & (~(df_hr.columns.str.contains("Unnamed")))]
df_hr["index"] = df_hr.index
df_hr.to_sql("hr_data", conn)

# %%
df_hr.groupby("DeptID",as_index=False).apply(lambda x: x[x.TermReason.str.contains("N/A")].count())



pd.read_sql("""SELECT * FROM (SELECT COUNT(TermReason) AS 'Headcount Per Department'
               FROM hr_data WHERE TermReason LIKE '%N/A%' 
               GROUP BY DeptID
               ORDER BY COUNT(TermReason) DESC)
               LEFT JOIN (SELECT COUNT(*) AS Leavers FROM hr_data WHERE TermReason NOT LIKE '%N/A%' 
               GROUP BY DeptID
               ORDER BY COUNT(TermReason) DESC) """,conn)

pd.read_sql("""SELECT (CAST(leavers as float)/CAST(all_employees AS float) ) as attrition_rate_by_dept FROM (SELECT (SUM(CASE WHEN TermReason NOT LIKE '%N/A%' THEN DeptID ELSE NULL END)) as leavers,
    (SUM(CASE WHEN TermReason IS NOT NULL 
    THEN DeptID ELSE NULL END)) AS all_employees
    FROM hr_data GROUP BY DeptID)""", conn)
# Out:
#    attrition_rate_by_dept
# 0                0.300000
# 1                     NaN
# 2                0.200000
# 3                0.300000
# 4                0.399038
# 5                0.156250

# %% [markdown]
# ### Text/Time Series Data

# %%
# Objective: Identifying self-organizing groups in the data (unsupervised), Generation Tasks
df_esg = pd.read_csv("./sample-data/ESG_daily_news.csv")
df_esg = df_esg.sort_values("Date",ascending=True)
df_esg.to_sql("esg_data",conn)

# %%
def search_for_keywords(keywords):
    '''
    search_for_keywords takes a keywords argument 
    :param keywords list:
    :return: pd.DataFrame 
    '''
    query = f"""SELECT * FROM esg_data WHERE 
             {" OR ".join([f"(headline LIKE '%{keyword}%')" for keyword in keywords])}"""
    return pd.read_sql(query, conn)

# %%
# search_for_keywords(["China", "Asia"])['headline'].tolist()

# %%
def filtering_by_date(start_date=None,end_date=None):
    query = "SELECT * FROM esg_data "
    add_ons = []
    if start_date is not None:
        add_ons.append(f"Date > '{start_date}'")
    if end_date is not None:
        add_ons.append(f"Date < '{end_date}'")
    query += " WHERE " + " AND ".join(add_ons)
    return pd.read_sql(query,conn).drop(columns=["index"])
filtering_by_date(str(datetime(2021,1,1)).split()[0],
                  str(datetime(2022,1,1)).split()[0])
# Out:
#           Date                                           headline  \
# 0   2021-10-21   China City Builders Buck Drop in Property Prices
# 38  2021-12-14  Pimco, Fidelity Steer Clear of Net-Zero Fund A...
# 39  2021-12-15  Goldman, BNY Mellon Join Fund Stampede With Ne...
# 40  2021-12-16  China Property Tycoons Lose $46 Billion of Wealth
# 41  2021-12-19  Ex-Bankers Lose Bid to Boost Credit Suisse Tax...
# 42  2021-12-20  WalMart Sued for Allegedly Dumping Hazardous W...
# 43  2021-12-21   Hedge Funds Seek Legal Advice for ‘Onerous’ Rule
# 44  2021-12-22  Musk Says He Has Further Reduced His Stake in ...
#
#                                                  text
# 0   A key part of China’s credit market is doing b...
# 1   Nations are edging toward a deal that might cr...
# 2   Rich countries have failed to meet their pledg...
# 3   Jet fuel is back in a big way. The oil product...
# 4   The doing-well-by-doing-good conviction drivin...
# 5   Citigroup Inc. is returning to the social bond...
# 6   China may be forced to start buying crude at e...
# 7   Credit Agricole passed BNP Paribas and gained ...
# 8   Teva Pharmaceutical is selling a record $5 bil...
# 9   Just a small handful of governments have imple...
# 10  Talks at COP26 on international carbon markets...
# 11  Singapore’s financial watchdog is turning to r...
# 12  Ford Motor priced $2.5 billion of bonds with p...
# 13  Citigroup plans to resume its public-finance b...
# 14  First it was China Evergrande. Then it was sma...
# 15  Mercury Retail Holding, which controls Russia’...
# 16  Akio Toyoda, the president of Toyota Motor, sp...
# 17  Jeremy Grantham got rich steering clients away...
# 18  One of Japan’s biggest industrial carbon-emitt...
# 19  Hedge funds are seeking riches from California...
# 20  JPMorgan Chase was removed from a $700 million...
# 21  Two of Europe’s banking giants selected leader...
# 22  The European Union plans to use technology to ...
# 23  President Joe Biden wants Americans to dramati...
# 24  China’s increasingly extreme Covid-zero polici...
# 25  The debt crisis engulfing the Chinese real est...
# 26  The cheapest coal in America has never been so...
# 27  As the dust settles on the finance industry’s ...
# 28  Chinese developers are facing $12 billion in t...
# 29  BNP Paribas is gaining ground on JPMorgan amon...
# 30  Japan is taking a cautious approach when it co...
# 31  Green mortgages are far from taking off in Eur...
# 32  Cathie Wood is preparing this week to launch o...
# 33  Given all the hype about ESG, one would expect...
# 34  Morgan Stanley’s asset management division has...
# 35  The defaults and slow-moving crises of compani...
# 36  Commonwealth Bank of Australia is joining the ...
# 37  When Tamao Sasada was put in charge of a large...
# 38  A group of fund-management giants has decided ...
# 39  The furious pace of green-fund launches in the...
# 40  Chinese real estate tycoons are having their w...
# 41  A U.S. judge dismissed a lawsuit by former Cre...
# 42  Walmart was sued by California for allegedly d...
# 43  An obscure rule covering ESG investing in Euro...
# 44  Has Elon Musk taken further steps to meaningfu...

# %%
# Storing data in SQL
